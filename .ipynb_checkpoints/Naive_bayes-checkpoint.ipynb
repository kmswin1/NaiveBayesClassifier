# %%
import pickle
import os
import sys
import numpy as np
import torch
import math

# %%
#-*- coding: euc-kr -*-

import pickle
import os
import sys
import numpy as np
import collections
sys.stdout.encoding

class NaiveBayesClassifier():

    def __init__(self):
        self.hamLogLikelihood = collections.defaultdict(lambda :0)
        self.spamLogLikelihood = collections.defaultdict(lambda: 0)
        self.hamWords = collections.defaultdict(lambda: 0)
        self.spamWords = collections.defaultdict(lambda: 0)
        self.spamPrior = 0.0
        self.hamPrior = 0.0
        self.totalHam = 0.0
        self.totalSpam = 0.0
        self.prior = 0.0
        self.train_data = []
        self.test_data = []

    def split_data(self):
        f = open('blog_spam.txt', 'r')
        data = f.read()
        data = data.split('\n')
        type(data)
        for i in range(len(data)-1):
            temp = data[i].split('\t')
            if (temp[0] == 'tr'):
                self.train_data.append(data)
            else:
                self.test_data.append(data)
        print ("split end")
        print (self.train_data[0][1])
        f.close()

    def make_table(self):
        print ("make table")
        for k in range(len(self.train_data)):
            if (self.train_data[k][1] == '정상'):
                print("ms")
                for i in range(3, len(self.train_data[k])):
                    self.hamWords[self.train_data[k][i]] += 1
                    self.totalHam += 1
            else:
                print("bn")
                for i in range(3, len(self.train_data[k])):
                    self.spamWords[self.train_data[k][i]] += 1
                    self.totalSpam += 1
        print ("end make table")

    def get_prob(self):
        self.split_data()
        self.make_table()
        with open("log.txt", 'w') as f:
            f.write("make_table complete\n")
        f.close()
        self.smoothing()
        with open("log.txt", 'w') as f:
            f.write("smoothing complete\n")
        f.close()
        self.hamPrior = np.log(float(self.totalHam)/(float(self.totalHam)+float(self.totalSpam)))
        self.spamPrior = np.log(float(self.totalSpam)/(float(self.totalHam)+float(self.totalHam)))
        self.prior = self.hamPrior - self.spamPrior
        for key in self.hamWords.keys():
            self.hamLogLikelihood[key] = np.log(float(self.hamWords[key])/(float(self.hamWords[key])+float(self.spamWords[key])))
            self.spamLogLikelihood[key] = np.log(float(self.spamWords[key]) / (float(self.hamWords[key]) + float(self.spamWords[key])))
        with open("log.txt", 'w') as f:
            f.write("get_prob complete\n")
        f.close()

    def smoothing(self):
        for key in self.spamWords.keys():
            if key not in self.hamWords.keys():
                self.spamWords[key] += 1

        for key in self.hamWords.keys():
            if key not in self.spamWords.keys():
                self.hamWords[key] += 1

    def test(self):
        result = ""
        accuracy = 0.0
        with open("result.txt", 'w') as f:
            with open("log.txt", 'w') as log:
                for i in range(len(self.test_data)):
                    sum = 0
                    for k in range(3,len(self.test_data[i])):
                        sum += (self.hamLogLikelihood[self.test_data[i]] - self.spamLogLikelihood[self.test_data[i]])
                    if (self.prior + sum > 0):
                        result = self.test_data[i][2]+"\t정상\t"
                        f.write(sum)
                        log.write("정상\n")
                        if self.test_data[i][1] == "정상":
                            accuracy += 1.0
                    else:
                        result = self.test_data[i][2]+"\t스펨\t"
                        log.write("스팸\n")
                        if self.test_data[i][1] != "정상":
                            accuracy += 1.0
                    if i % 10000 == 0:
                        print("%d.iter") % i
                accuracy /= (self.totalHam+self.totalSpam)
                print ("accuracy : %d") % accuracy
                log.write(str(accuracy))
            log.close()
        f.close()

# %%
# -*- coding: utf-8 -*-
import NaiveBayes as nb
import numpy as np
import pickle
import os
import sys

if __name__ == "__main__":
    naive = nb.NaiveBayesClassifier()
    print ("start calculate prob!!")
    naive.get_prob()
    print ("calculate complete!")
    print ("start test!!")
    naive.test()
    print ("test")
# Out:
# start calculate prob!!
# UTF-8
# split end
# tr	정상	fc67c66a317686ed4bb3d6a23db2ac70	2016.2.26	금요일	점심	은평	구	대조동	남정네	부엌	곳	점심	배려	아이콘	소고기	크림	파스타
# make table
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# sm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8b699bd04ac9> in <module>
#       9     naive = nb.NaiveBayesClassifier()
#      10     print ("start calculate prob!!")
# ---> 11     naive.get_prob()
#      12     print ("calculate complete!")
#      13     print ("start test!!")
#
# ~/NaiveBayes/NaiveBayes.py in get_prob(self)
#      55     def get_prob(self):
#      56         self.split_data()
# ---> 57         self.make_table()
#      58         with open("log.txt", 'w') as f:
#      59             f.write("make_table complete\n")
#
# ~/NaiveBayes/NaiveBayes.py in make_table(self)
#      49                 print("sm")
#      50                 for i in range(3, len(self.train_data[k])):
# ---> 51                     self.spamWords[self.train_data[k][i]] += 1
#      52                     self.totalSpam += 1
#      53         print ("end make table")
#
# KeyboardInterrupt:

# %%
f = open('blog_spam.txt','r')
ham = {}
spam = {}
data = f.read()
data = data.split('\n')
data = data[29999].split('\t')
print (data[6])
#for i in range(len(data)-1)
# Out:
# 바카라
